# %%
import pandas as pd
data = pd.read_csv("../data/data_preprossing.csv")
data.shape
# Out:
# (652, 13)

# %%
data.head()
# Out:
#          Date                                   IPO_Name  Issue_Size(crores)  \
# 0  2025-08-06                      M & B Engineering Ltd              650.00
# 1  2025-08-06          Sri Lotus Developers & Realty Ltd              792.00
# 2  2025-08-06  National Securities Depository Ltd (NSDL)             4011.60
# 3  2025-08-05                        Aditya Infotech Ltd             1300.00
# 4  2025-08-05                    Laxmi India Finance Ltd              254.26
#
#       QIB    HNI    RII   Total  Offer Price  List Price  Listing Gain  \
# 0   36.72  38.24  32.55   36.20          385       386.0          0.26
# 1  163.90  57.71  20.28   69.14          150       179.1         19.40
# 2  103.97  34.98   7.73   41.01          800       880.0         10.00
# 3  133.21  72.00  50.87  100.69          675      1018.0         50.81
# 4    1.30   1.84   2.22    1.87          158       136.0        -13.92
#
#    CMP(BSE)  CMP(NSE)  Current Gains
# 0    426.85    426.15          10.87
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

X = data.drop(["List Price", "IPO_Name", "Date"] ,axis = 1)
y = data["List Price"]

X_train,X_test,y_train,y_test = train_test_split(X,y , test_size = 0.20 , random_state = 1)

D_model = DecisionTreeRegressor(min_samples_split = 5 , max_depth = 5 ,min_samples_leaf = 2 , random_state = 1 )

model.fit(X_train , y_train)
D_pred = model.predict(X_test)
print(D_pred[:10])
# Out:
# [ 36.54666667  82.71780488  82.71780488 112.52830508 763.73
#  159.035      283.26935484 484.56363636 897.97352941 283.26935484]

# %%
comperison = pd.DataFrame({
    "Actual price" : y_test,
    "predicted price" : D_pred
})
print(comperison)
# Out:
#      Actual price  predicted price
# 465         10.10        36.546667
# 441         55.80        82.717805
# 593         52.13        82.717805
# 458        110.00       112.528305
# 41         660.00       763.730000
# ..            ...              ...
# 195        360.50       325.636905
# 135        137.75       112.528305
# 411        313.00       325.636905
# 159        163.30       159.035000
# 250        141.00       159.035000
#
# [131 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error ,  r2_score
import numpy as np
print("MAE :", mean_absolute_error(y_test, D_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, D_pred)))
print("R2  :", r2_score(y_test, D_pred))
# Out:
# MAE : 48.74991230464462
# RMSE: 76.26348149435971
# R2  : 0.9676485387809233

# %%
import joblib
joblib.dump(D_model , "Decision_tree.pkl")
# Out:
# ['Decision_tree.pkl']
